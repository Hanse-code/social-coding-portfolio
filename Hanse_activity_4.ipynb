# %% [markdown]
# <a href="https://colab.research.google.com/github/Hanse-code/social-coding-portfolio/blob/main/Hanse_activity_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def intro():
    print("Welcome, Tarnished, to the Lands Between.")
    print("The Elden Ring has been shattered, and the world is in chaos.")
    print("Your journey begins as you stand at the crossroads.")
    print("Do you:")
    print("1. Enter the misty forest to the north.")
    print("2. Approach Stormveil Castle to the west.")

    choice = input("Enter 1 or 2: ")

    if choice == '1':
        forest_path()
    elif choice == '2':
        stormveil_castle()
    else:
        print("Invalid choice, please select 1 or 2.")
        intro()

def forest_path():
    print("\nYou enter the misty forest. The trees are dense, and an eerie fog hangs in the air.")
    print("Suddenly, a figure steps from the shadows—a hostile creature known as a tree sentinel.")
    print("Do you:")
    print("1. Fight the tree sentinel.")
    print("2. Attempt to sneak past it.")

    choice = input("Enter 1 or 2: ")

    if choice == '1':
        fight_tree_sentinel()
    elif choice == '2':
        sneak_past()
    else:
        print("Invalid choice, please select 1 or 2.")
        forest_path()

def stormveil_castle():
    print("\nYou make your way to Stormveil Castle. The imposing walls loom above you, a fortress of the Golden Order.")
    print("As you walk towards the entrance, the ground shakes. A massive figure steps forward—it is Godfrey, the First Elden Lord.")
    print("He roars and readies his great axe.")
    print("Do you:")
    print("1. Charge at him with all your strength.")
    print("2. Wait and observe, looking for an opening to dodge his attacks.")

    choice = input("Enter 1 or 2: ")

    if choice == '1':
        charge_at_godfrey()
    elif choice == '2':
        wait_and_dodge()
    else:
        print("Invalid choice, please select 1 or 2.")
        stormveil_castle()

def fight_tree_sentinel():
    print("\nYou raise your weapon to fight the tree sentinel. The battle is fierce, and the sentinel's attacks are strong.")
    print("You narrowly defeat the creature, but it leaves you wounded. However, you find a mysterious rune in its possession.")
    print("You gain a powerful ability that may aid you in future battles.")
    print("You continue your journey deeper into the forest.")

def sneak_past():
    print("\nYou quietly sneak past the tree sentinel, avoiding its gaze. The forest grows darker, and you hear distant howls.")
    print("You discover a hidden grove containing a rare healing herb, which restores some of your strength.")
    print("You continue through the forest, uncertain of what lies ahead.")

# Battle with Godfrey

def charge_at_godfrey():
    print("\nYou charge forward, weapons drawn, but Godfrey's strength is overwhelming. He swings his great axe with deadly precision.")
    print("You fail to dodge his first blow, and your body is thrown backward. You die in the clash.")
    print("You have fallen before Godfrey. The Lands Between are full of peril.")
    print("Game Over.")

def wait_and_dodge():
    print("\nYou decide to wait and observe Godfrey's movements. His fiery breath fills the air.")
    print("As he prepares to unleash a devastating fire attack, you time your dodge perfectly and roll to safety.")
    print("You land a quick counterattack, but Godfrey is far from defeated. He roars in fury.")
    print("The battle rages on...")

    print("Do you:")
    print("1. Continue dodging and looking for openings.")
    print("2. Go all-in with a risky final attack while he's recovering.")

    choice = input("Enter 1 or 2: ")

    if choice == '1':
        continue_dodging()
    elif choice == '2':
        risky_attack()
    else:
        print("Invalid choice, please select 1 or 2.")
        wait_and_dodge()

def continue_dodging():
    print("\nYou continue dodging Godfrey's fiery breath and powerful axe swings.")
    print("Finally, you spot an opening and unleash a devastating combo, landing the final blow!")
    print("Godfrey falls to the ground, defeated, and the castle shakes with his demise.")
    print("You stand victorious, but there is still much to be done in the Lands Between.")
    cliffhanger()

def risky_attack():
    print("\nYou take a risky chance and charge at Godfrey with all your might while he's recovering from the fire breath.")
    print("However, Godfrey recovers faster than expected and lands a crushing blow to you before you can strike.")
    print("The battle ends in your defeat. You have fallen.")
    print("Game Over.")

# Cliffhanger after defeating Godfrey

def cliffhanger():
    print("\nAfter defeating Godfrey, you find a mysterious scroll on his body.")
    print("It mentions something about a powerful force stirring in Liurnia of the Lakes.")
    print("You gather your belongings and head toward the unknown, knowing your true test lies ahead.")
    print("To be continued...")

# Start the game
intro()
# Out:
# Welcome, Tarnished, to the Lands Between.
# The Elden Ring has been shattered, and the world is in chaos.
# Your journey begins as you stand at the crossroads.
# Do you:
# 1. Enter the misty forest to the north.
# 2. Approach Stormveil Castle to the west.
# Enter 1 or 2: 1
# Enter 1 or 2: 1
#
# You enter the misty forest. The trees are dense, and an eerie fog hangs in the air.
# Suddenly, a figure steps from the shadows—a hostile creature known as a tree sentinel.
# Do you:
# 1. Fight the tree sentinel.
# 2. Attempt to sneak past it.
#
# You raise your weapon to fight the tree sentinel. The battle is fierce, and the sentinel's attacks are strong.
# You narrowly defeat the creature, but it leaves you wounded. However, you find a mysterious rune in its possession.
# You gain a powerful ability that may aid you in future battles.
# You continue your journey deeper into the forest.

# %%
def intro():
    print("Welcome, Tarnished, to the Lands Between.")
    print("The Elden Ring has been shattered, and the world is in chaos.")
    print("Your journey begins as you stand at the crossroads.")
    print("Do you:")
    print("1. Enter the misty forest to the north.")
    print("2. Approach Stormveil Castle to the west.")

    choice = input("Enter 1 or 2: ")

    if choice == '1':
        forest_path()
    elif choice == '2':
        stormveil_castle()
    else:
        print("Invalid choice, please select 1 or 2.")
        intro()

def forest_path():
    print("\nYou enter the misty forest. The trees are dense, and an eerie fog hangs in the air.")
    print("Suddenly, a figure steps from the shadows—a hostile creature known as a tree sentinel.")
    print("Do you:")
    print("1. Fight the tree sentinel.")
    print("2. Attempt to sneak past it.")

    choice = input("Enter 1 or 2: ")

    if choice == '1':
        fight_tree_sentinel()
    elif choice == '2':
        sneak_past()
    else:
        print("Invalid choice, please select 1 or 2.")
        forest_path()

def stormveil_castle():
    print("\nYou make your way to Stormveil Castle. The imposing walls loom above you, a fortress of the Golden Order.")
    print("As you walk towards the entrance, the ground shakes. A massive figure steps forward—it is Godfrey, the First Elden Lord.")
    print("He roars and readies his great axe.")
    print("Do you:")
    print("1. Charge at him with all your strength.")
    print("2. Wait and observe, looking for an opening to dodge his attacks.")

    choice = input("Enter 1 or 2: ")

    if choice == '1':
        charge_at_godfrey()
    elif choice == '2':
        wait_and_dodge()
    else:
        print("Invalid choice, please select 1 or 2.")
        stormveil_castle()

def fight_tree_sentinel():
    print("\nYou raise your weapon to fight the tree sentinel. The battle is fierce, and the sentinel's attacks are strong.")
    print("You narrowly defeat the creature, but it leaves you wounded. However, you find a mysterious rune in its possession.")
    print("You gain a powerful ability that may aid you in future battles.")
    print("You continue your journey deeper into the forest.")

    print("Do you:")
    print("1. Keep moving toward the deeper parts of the forest.")
    print("2. Search the area for any hidden secrets or items.")

    choice = input("Enter 1 or 2: ")

    if choice == '1':
        deeper_forest_path()
    elif choice == '2':
        hidden_secrets()
    else:
        print("Invalid choice, please select 1 or 2.")
        fight_tree_sentinel()

def sneak_past():
    print("\nYou quietly sneak past the tree sentinel, avoiding its gaze. The forest grows darker, and you hear distant howls.")
    print("You discover a hidden grove containing a rare healing herb, which restores some of your strength.")
    print("You continue through the forest, uncertain of what lies ahead.")

    print("Do you:")
    print("1. Continue on your path, trying to find an exit.")
    print("2. Rest in the grove and regain your strength.")

    choice = input("Enter 1 or 2: ")

    if choice == '1':
        continue_path()
    elif choice == '2':
        rest_and_heal()
    else:
        print("Invalid choice, please select 1 or 2.")
        sneak_past()

def continue_path():
    print("\nYou continue along the path and eventually find your way out of the misty forest.")
    print("The sun begins to set, and you hear the distant sound of water, hinting that you are near Liurnia of the Lakes.")
    cliffhanger()

def rest_and_heal():
    print("\nYou decide to rest and regain your strength. During your rest, you hear faint footsteps approaching.")
    print("You prepare for an ambush, but it turns out to be a fellow Tarnished who offers you a healing potion.")
    print("You gain a new ally on your journey.")
    print("After your rest, you resume your journey.")

    cliffhanger()

def deeper_forest_path():
    print("\nYou venture deeper into the forest, and the trees grow even denser. Suddenly, a pack of wolves surrounds you.")
    print("Do you:")
    print("1. Fight the wolves.")
    print("2. Try to scare them off by shouting and waving your weapon.")

    choice = input("Enter 1 or 2: ")

def fight_wolves():
    print("\nYou draw your weapon and prepare for battle with the wolves. They are fast and vicious, but you manage to hold your ground.")
    print("After a tough battle, you defeat the pack, though you are left injured.")
    print("You find a hidden cave nearby and decide to rest.")

    print("Do you:")
    print("1. Rest in the cave and heal your wounds.")
    print("2. Continue your journey, leaving the cave behind.")

    choice = input("Enter 1 or 2: ")

    if choice == '1':
        rest_in_cave()
    elif choice == '2':
        continue_journey()
    else:
        print("Invalid choice, please select 1 or 2.")
        fight_wolves()

def rest_in_cave():
    print("\nYou rest in the cave, regaining some strength. During your rest, you hear faint whispers in the wind.")
    print("The whispers speak of a hidden power in Liurnia of the Lakes, an ancient force waiting to be awakened.")
    print("You feel stronger and ready for what lies ahead.")

    cliffhanger()

def continue_journey():
    print("\nYou leave the cave and continue your journey. The path ahead remains unclear, but you press on.")
    print("The sky above darkens as you move deeper into the forest, and the unknown awaits.")

    cliffhanger()

    if choice == '1':
        fight_wolves()
    elif choice == '2':
        scare_wolves()
    else:
        print("Invalid choice, please select 1 or 2.")
        deeper_forest_path()

def hidden_secrets():
    print("\nYou search the area and uncover an old chest hidden beneath the roots of a large tree.")
    print("Inside the chest, you find a powerful sword and a scroll detailing the hidden history of the Elden Ring.")
    print("This knowledge might be helpful in your future quests.")

    cliffhanger()

# Battle with Godfrey

def charge_at_godfrey():
    print("\nYou charge forward, weapons drawn, but Godfrey's strength is overwhelming. He swings his great axe with deadly precision.")
    print("You fail to dodge his first blow, and your body is thrown backward. You die in the clash.")
    print("You have fallen before Godfrey. The Lands Between are full of peril.")
    print("Game Over.")

def wait_and_dodge():
    print("\nYou decide to wait and observe Godfrey's movements. His fiery breath fills the air.")
    print("As he prepares to unleash a devastating fire attack, you time your dodge perfectly and roll to safety.")
    print("You land a quick counterattack, but Godfrey is far from defeated. He roars in fury.")
    print("The battle rages on...")

    print("Do you:")
    print("1. Continue dodging and looking for openings.")
    print("2. Go all-in with a risky final attack while he's recovering.")

    choice = input("Enter 1 or 2: ")

    if choice == '1':
        continue_dodging()
    elif choice == '2':
        risky_attack()
    else:
        print("Invalid choice, please select 1 or 2.")
        wait_and_dodge()

def continue_dodging():
    print("\nYou continue dodging Godfrey's fiery breath and powerful axe swings.")
    print("Finally, you spot an opening and unleash a devastating combo, landing the final blow!")
    print("Godfrey falls to the ground, defeated, and the castle shakes with his demise.")
    print("You stand victorious, but there is still much to be done in the Lands Between.")
    cliffhanger()

def risky_attack():
    print("\nYou take a risky chance and charge at Godfrey with all your might while he's recovering from the fire breath.")
    print("However, Godfrey recovers faster than expected and lands a crushing blow to you before you can strike.")
    print("The battle ends in your defeat. You have fallen.")
    print("Game Over.")

# Cliffhanger after defeating Godfrey

def cliffhanger():
    print("\nAfter defeating Godfrey, you find a mysterious scroll on his body.")
    print("It mentions something about a powerful force stirring in Liurnia of the Lakes.")
    print("You gather your belongings and head toward the unknown, knowing your true test lies ahead.")
    print("To be continued...")

# Start the game
intro()
# Out:
# Welcome, Tarnished, to the Lands Between.
# The Elden Ring has been shattered, and the world is in chaos.
# Your journey begins as you stand at the crossroads.
# Do you:
# 1. Enter the misty forest to the north.
# 2. Approach Stormveil Castle to the west.
# Enter 1 or 2: 1
#
# You enter the misty forest. The trees are dense, and an eerie fog hangs in the air.
# Suddenly, a figure steps from the shadows—a hostile creature known as a tree sentinel.
# Do you:
# 1. Fight the tree sentinel.
# 2. Attempt to sneak past it.
# Enter 1 or 2: 1
#
# You raise your weapon to fight the tree sentinel. The battle is fierce, and the sentinel's attacks are strong.
# You narrowly defeat the creature, but it leaves you wounded. However, you find a mysterious rune in its possession.
# You gain a powerful ability that may aid you in future battles.
# You continue your journey deeper into the forest.
# Do you:
# 1. Keep moving toward the deeper parts of the forest.
# ...
